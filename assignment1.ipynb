# %%
print("helloworld")
# Out:
# helloworld

# %%
a = 15
b = 4
sum = a+b
print("sum is " , sum)
differ = a - b
print( "differnce is ", differ)
product = a * b 
print("product is", product)
division = a / b 
print("division is", division) 
floorDivision = a // b 
print("floordivision is", floorDivision) 
modulus = a % b 
print("modulus is", modulus)
# Out:
# sum is  19
# differnce is  11
# product is 60
# division is 3.75
# floordivision is 3
# modulus is 3

# %%
favouriteFood  = "biryani"
print("my favourite food is", favouriteFood)
# Out:
# my favourite food is biryani

# %%
apples = 22
mangoes = 33 
fruits = apples + mangoes 
print("fruits is", fruits)
# Out:
# fruits is 55

# %%
x = 10 
y = float(x) 
print(y) 
print(type(y))
# Out:
# 10.0
# <class 'float'>

# %%
x = 5.6
y = int(x) 
print(y)
print(type(y))
# Out:
# 5
# <class 'int'>

# %%
x = 4.43
y = str(x)
print(y)
print(type(y))
# Out:
# 4.43
# <class 'str'>

# %%
x = '23'
y = int(x)
print(y)
print(type(y))
# Out:
# 23
# <class 'int'>

# %%
a = ' lahan kashif' 
b =  20
c = sum = b + 1 
print("lahan kashif age is", c)
# Out:
# lahan kashif age is 21

# %%
a = 2
b = 1
c = 6
d = 3
sum = a + b
print("sum of a + b is", sum)  
subtraction = c - a 
print("subtraction of c - a is", subtraction) 
multiplication = d * b 
print("multiplication of d*b is", multiplication) 
result = b / d 
print("division of b * d is ", result) 
modulus = c % d
print("modulus of c % d is", modulus) 
square = (d + a) ** 2 
print("square of (d + a) ** 2 is", square)
# Out:
# sum of a + b is 3
# subtraction of c - a is 4
# multiplication of d*b is 3
# division of b * d is  0.3333333333333333
# modulus of c % d is 0
# square of (d + a) ** 2 is 25

# %%
age = '20' 
sum = '20 + 5'
print("age  is", age)
# Out:
# age  is 20

# %%
a = '2'
b = '11'
c = 6.3
a = int(a)
results = a + int(c)
print(results) 
print("results is", results)  
b = float(b)
result = b * c
print("result is", result) 
c = int(c)
result = c + c 
print("result is", result)
# Out:
# 8
# results is 8
# result is 69.3
# result is 12

# %%
books = 12
difference = books - 4 
result = books - 4 
print("result is", result)
# Out:
# result is 8
