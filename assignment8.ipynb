# %%
# Employee Class

class Employee:
    def __init__(self, name, number, address, salary, post, year_of_joining, education, year_of_experience):
        self.name = name
        self.number = number
        self.address = address
        self.salary = salary
        self.post = post
        self.year_of_joining = year_of_joining
        self.education = education
        self.year_of_experience = year_of_experience
    def describe_employee(self):
        print("Name:", self.name)
        print("EmployeeNumber:", self.number)
        print("Address:", self.address)
        print("Salary:", self.salary)
        print("Post:", self.post)
        print("Year of Joining:", self.year_of_joining)
        print("Education:", self.education)
        print("Years of Experience:", self.year_of_experience)
    def update_year_of_experience(self, years):
        self.year_of_experience += years
        print("{self.name}'s experience updated to {self.year_of_experience} years.")
        def increase_salary(self, amount):
            self.salary += amount
print("{self.name}'s new salary is {self.salary}.")
employee101 = Employee(
    "Ahmed",
    101,
    "Karachi",
    50000,
    "Software Engineer",
    2022,
    "CS",
    2
)
print("Name:", employee101.name)
print("Number:", employee101.number)
print("Salary:", employee101.salary)
print("Post:", employee101.post)
employee101.describe_employee()
employee101.update_year_of_experience(3)
# Out:
# {self.name}'s new salary is {self.salary}.
# Name: Ahmed
# Number: 101
# Salary: 50000
# Post: Software Engineer
# Name: Ahmed
# EmployeeNumber: 101
# Address: Karachi
# Salary: 50000
# Post: Software Engineer
# Year of Joining: 2022
# Education: CS
# Years of Experience: 2
# {self.name}'s experience updated to {self.year_of_experience} years.
