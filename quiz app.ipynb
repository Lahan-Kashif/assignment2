# %%
score = 0
Question1 =["What did the IP stands for?"]
print("A. Informatin Process")
print("B. Input Process")
print("C. Internal Protocol")
print("D. Ineternet Processor")

answer = input("Enter your answer (A/B/C/D): ")

if answer.upper() == "C":
    print("Correct!\n")
    score += 1
    
else:
    print("Wrong!\n")

Question2 = ["Which method adds an element to the end of a list?"]
print("A. if")
print("B. append")
print("C. def")
print("D. class")

answer = input("Enter your answer (A/B/C/D): ")

if answer.upper() == "B":
    print("Correct!\n")
    score += 1
else:
    print("Wrong!\n")

Qusion3 = ["Which data type stores unique values only?"]
print("A. Tuple")
print("B. Dictionary")
print("C. set")
print("D. list")

answer = input("Enter your answer (A/B/C/D): ")

if answer.upper() == "C":
    print("Correct!\n")
    score += 1
else:
    print("Wrong!\n")

Question4 = ["Which symbol is used to create a dictionary?"]
print("A.( )")
print("B.[ ]")
print("C.{ }")
print("D.< >")
answer = input("Enter your answer (A/B/C/D): ")
if answer.upper() == "C":
    print("Correct!\n")
    score += 1
else:
    print("Wrong!\n")

Question5 = ["Which method removes duplicate values from a list?"]
print("A.remove()")    
print("B.pop()")
print("C.set()")
print("D.append()")
anser = input("Enter your answer (A/B/C/D): ")
if answer.upper() == "C":
    print("Correct!\n")
    score += 1
else:
    print("Wrong!\n")

sum = ["scores"]
Total_Score = ["4/5"]
print("Quiz Completed!")
print("Your total score is:", score, "/ 5")
print("Excellent")
# Out:
# A. Informatin Process
# B. Input Process
# C. Internal Protocol
# D. Ineternet Processor
# Correct!
#
# A. if
# B. append
# C. def
# D. class
# Wrong!
#
# A. Tuple
# B. Dictionary
# C. set
# D. list
# Correct!
#
# A.( )
# B.[ ]
# C.{ }
# D.< >
# Correct!
#
# A.remove()
# B.pop()
# C.set()
# D.append()
# Correct!
#
# Quiz Completed!
# Your total score is: 4 / 5
# Excellent
