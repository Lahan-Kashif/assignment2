# %%
products = { 101: {"name": "Laptop", "category": "Electronics", "price": 1200, "stock": 50}, 102: {"name": "Shirt", "category": "Apparel", "price": 25, "stock": 200}, 103: {"name": "Coffee Maker", "category": "Home Appliances", "price": 80, "stock": 30} } 
var = products[102]
var["stock"] = 250
print(products) 
products[104] = {"name":"smartphone", "category": "electronics", "price": 1200, "stock":50}
print(products)
# Out:
# {101: {'name': 'Laptop', 'category': 'Electronics', 'price': 1200, 'stock': 50}, 102: {'name': 'Shirt', 'category': 'Apparel', 'price': 25, 'stock': 250}, 103: {'name': 'Coffee Maker', 'category': 'Home Appliances', 'price': 80, 'stock': 30}}
# {101: {'name': 'Laptop', 'category': 'Electronics', 'price': 1200, 'stock': 50}, 102: {'name': 'Shirt', 'category': 'Apparel', 'price': 25, 'stock': 250}, 103: {'name': 'Coffee Maker', 'category': 'Home Appliances', 'price': 80, 'stock': 30}, 104: {'name': 'smartphone', 'category': 'electronics', 'price': 1200, 'stock': 50}}

# %%
employe = ("Ali",25,"Data Analyst",75000)
name, age ,work ,salary = employe
print("name")
print(age)
print("work")
print(salary)
salary = salary + (salary *10/100)
print(name)
print(salary)
# Out:
# name
# 25
# work
# 75000
# Ali
# 82500.0

# %%
shopping_list = ["apple", "banana", "apple", "orange", "banana", "grape"]
shopping_listset = set(shopping_list)
print(shopping_listset) 
shopping_list2 = list(shopping_listset)
print(shopping_list2)
# Out:
# {'banana', 'orange', 'grape', 'apple'}
# ['banana', 'orange', 'grape', 'apple']

# %%
Course_A = {"John", "Alice", "Bob", "David"}
Course_B = {"Alice", "Eve", "Charlie", "David"}
students = Course_A - Course_B
print(students)
students = Course_A^Course_B
print(students)
# Out:
# {'John', 'Bob'}
# {'John', 'Eve', 'Bob', 'Charlie'}

# %%
numbers = (10, 20, 30, 40, 50, 60, 70)
print(numbers[:3])
print(numbers[-3:])
print(numbers[::2])
# Out:
# (10, 20, 30)
# (50, 60, 70)
# (10, 30, 50, 70)

# %%
student_details = { "Ali": {"age": 20, "grade": "A", "city": "Karachi"}, "Sara": {"age": 21, "grade": "B", "city": "Lahore"}, "Omar": {"age": 19, "grade": "A", "city": "Islamabad"}, "Hina": {"age": 22, "grade": "C", "city": "Faisalabad"} }
student_details["zara"] = {"age": 20, "grade": "B", "city": "Multan"} 
print(student_details)
student_details.pop('Omar')     
print(student_details)
# Out:
# {'Ali': {'age': 20, 'grade': 'A', 'city': 'Karachi'}, 'Sara': {'age': 21, 'grade': 'B', 'city': 'Lahore'}, 'Omar': {'age': 19, 'grade': 'A', 'city': 'Islamabad'}, 'Hina': {'age': 22, 'grade': 'C', 'city': 'Faisalabad'}, 'zara': {'age': 20, 'grade': 'B', 'city': 'Multan'}}
# {'Ali': {'age': 20, 'grade': 'A', 'city': 'Karachi'}, 'Sara': {'age': 21, 'grade': 'B', 'city': 'Lahore'}, 'Hina': {'age': 22, 'grade': 'C', 'city': 'Faisalabad'}, 'zara': {'age': 20, 'grade': 'B', 'city': 'Multan'}}

# %%
inventory = {"The Great Gatsby": {"price": 10.99,"quantity": 5},"Rich dad poor dad": {"price":8.99,"quantity":8},"Harry Potter": {"price": 12.50,"quantity": 2}}
inventory.update({"The python": {"price":16.99, "quantity":7}})
print(inventory)
inventory.pop("Harry Potter")
print(inventory)
# Out:
# {'The Great Gatsby': {'price': 10.99, 'quantity': 5}, 'Rich dad poor dad': {'price': 8.99, 'quantity': 8}, 'Harry Potter': {'price': 12.5, 'quantity': 2}, 'The python': {'price': 16.99, 'quantity': 7}}
# {'The Great Gatsby': {'price': 10.99, 'quantity': 5}, 'Rich dad poor dad': {'price': 8.99, 'quantity': 8}, 'The python': {'price': 16.99, 'quantity': 7}}

# %%
d = {"x": 1, "y": 2}
print(d)
# Out:
# {'x': 1, 'y': 2}

# %%
A = {"Ali", "Sara"}
B = {"Ahmed", "Zara"}
result = A.union(B)
print(result)
# Out:
# {'Ahmed', 'Sara', 'Zara', 'Ali'}

# %%
A = {1, 2, 3, 4, 5}
B = {4, 5, 6, 7}    
common = A & B
print(common)
result = A - B
print(result)
result2 = B - A
print(result2)
# Out:
# {4, 5}
# {1, 2, 3}
# {6, 7}
