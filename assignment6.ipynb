# %%
secret_code = "python"
guess = input("guess the word: ")
if guess == secret_code:
    print("you guessed it")
else:
    print("you did not guessed it")
# Out:
# you guessed it

# %%
users = ["Ali","Sara","Mike"]
for user in users:
    print(user)
for user in users:
    if user == "Sara":
        break 
print(user)
# Out:
# Ali
# Sara
# Mike
# Sara

# %%
temps = [22,25,30,45,28] 
critical = 40
temperature = input("monitor the temperature")
for temperature in temps:
    print(temperature)
for temperature in temps:
    if temperature == 40:
        break
    print(critical) 
    if temperature == 40:
        print("critical temperatur reached")
# Out:
# 22
# 25
# 30
# 45
# 28
# 40
# 40
# 40
# 40
# 40

# %%
carts = [100,250,50,300]
total = 0
for cart in carts:
    total = total + cart
print(total)
# Out:
# 700

# %%
emails = ["ali@gmail.com","sara@yahoo.com","john@hotmail.com"]
for email in emails:
    domain = email.split("@")[1]
print(domain)
# Out:
# hotmail.com

# %%
tasks = [ {"task": "Pay bills", "status": "done"},

{"task": "Submit report", "status": "pending"},

{"task": "Clean house", "status": "pending"}
] 
for task in tasks:
    if task["status"] == "Overdue":
        print(task)

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
for day in days:
    if day == "Saturday" or day == "Sunday":
        continue
    print(day)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday

# %%
users = ["Ali", "Sara", "John"]
for user in users:
    print("Hello Ali, your subscription is active!")
    print("Hello Sara, your subscription is active!") 
    print("Hello John, your subscription is active!")
# Out:
# Hello Ali, your subscription is active!
# Hello Sara, your subscription is active!
# Hello John, your subscription is active!
# Hello Ali, your subscription is active!
# Hello Sara, your subscription is active!
# Hello John, your subscription is active!
# Hello Ali, your subscription is active!
# Hello Sara, your subscription is active!
# Hello John, your subscription is active!
