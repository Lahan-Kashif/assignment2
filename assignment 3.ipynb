# %%
numbers = [1,2,3]
numbers.append(10)
print(numbers)
# Out:
# [1, 2, 3, 10]

# %%
order = ["burger","fries","coke"]
order.append("ice cream")
print(order)
order = ["burger","fries","coke"]
order.append("biryani")
print(order)
order.remove("biryani")
# Out:
# ['burger', 'fries', 'coke', 'ice cream']
# ['burger', 'fries', 'coke', 'biryani']

# %%
numbers=[4,1,3,2] 
ascending = sorted(numbers)
print(ascending)
# Out:
# [1, 2, 3, 4]

# %%
passangers = ["Ali","Zara","Ahmed"]
passangers.insert(0,"Sara")
print(passangers)
passangers.remove("Zara")
# Out:
# ['Sara', 'Ali', 'Zara', 'Ahmed']

# %%
passangers = ["Ali","Zara","Ahmed"]
passangers.reverse()
print(passangers)
# Out:
# ['Ahmed', 'Zara', 'Ali']

# %%
text = 'hello python world'
text = text.replace(' ', '_')
print(text)
text =  hello_python_world
parts = text.split("_")
print(parts)
# Out:
# hello_python_world
# ['hello', 'python', 'world']

# %%
text =  "hello_python_world"
result = text.replace("_", "-"   )
print(result)
# Out:
# hello-python-world

# %%
word = "javascript"
if len(word) > 5:
    print("more than 5 characters")
# Out:
# more than 5 characters

# %%
cities = ["Karachi","Lahore","Islamabad","Quetta"]
cities.reverse()
print (cities)
# Out:
# ['Quetta', 'Islamabad', 'Lahore', 'Karachi']

# %%
text = "Data analysis with python is very powerful"
result = text.strip()
print(result)
# Out:
# Data analysis with python is very powerful

# %%
text = "Data analysis with python is very powerful"
result = text.title()
print(result)
# Out:
# Data Analysis With Python Is Very Powerful

# %%
text = "Data analysis with python is very powerful"
result = text.replace("powerful","important")
print(result)
# Out:
# Data analysis with python is very important

# %%
text = "Data analysis with python is very powerful"
position = text.find("python")
print(position)
# Out:
# 19

# %%
data = [12,45,2,67,34,89,23,90]
ascending = sorted(data)
print(ascending)
# Out:
# [2, 12, 23, 34, 45, 67, 89, 90]

# %%
data = [12,45,2,67,34,89,23,90]
result = data.remove(90)
print(result)
# Out:
# None

# %%
data = [12,45,2,67,34,89,23,90]
data.insert(3,50)
print(data)
# Out:
# [12, 45, 2, 50, 67, 34, 89, 23, 90]

# %%
data = [12,45,2,67,34,89,23,90]
data.reverse()
print(data)
# Out:
# [90, 23, 89, 34, 67, 2, 45, 12]
